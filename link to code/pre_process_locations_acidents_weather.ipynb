# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

# %%
collisions = pd.read_csv("h2017collisionsfinal.csv")

# %% [markdown]
# Get first 50 rows for demo

# %%
collisions = collisions.loc[:50]

# %%
collisions
# Out:
#     Record                                           Location             X  \
# 0        1           210 W OF MERIVALE RD @ WEST HUNT CLUB RD  365431.70335
# 1        2           210 W OF MERIVALE RD @ WEST HUNT CLUB RD  365430.63705
# 2        3           210 W OF MERIVALE RD @ WEST HUNT CLUB RD  365431.70110
# 3        4           210 W OF MERIVALE RD @ WEST HUNT CLUB RD  365431.35217
# 4        5           210 W OF MERIVALE RD @ WEST HUNT CLUB RD  365432.02107
# 5        6           210 W OF MERIVALE RD @ WEST HUNT CLUB RD  365431.70282
# 6        7    225 E OF RIVERSIDE DR / T & T SC @ HUNT CLUB RD  368235.69760
# 7        8                             2ND LINE RD @ CABIN RD  375653.18807
# 8        9       2ND LINE RD btwn OSGOODE MAIN ST & HUGH CRES  376117.45339
# 9       10         4TH LINE RD btwn FOREST RD & SPRINGHILL RD  379732.32137
# 10      11         4TH LINE RD btwn FOREST RD & SPRINGHILL RD  379995.18692
# 11      12        4TH LINE RD btwn MCDIARMID RD & BELMEADE RD  382056.29935
# 12      13                          8TH LINE RD @ GLENWOOD DR  385888.54250
# 13      14                       8TH LINE RD @ MITCH OWENS RD  382361.93290
# 14      15                       8TH LINE RD @ MITCH OWENS RD  382363.24283
# 15      16                       8TH LINE RD @ MITCH OWENS RD  382361.80636
# 16      17                       8TH LINE RD @ MITCH OWENS RD  382361.80636
# 17      18                           8TH LINE RD @ PARKWAY RD  383165.52916
# 18      19                           8TH LINE RD @ PARKWAY RD  383166.74125
# 19      20                        8TH LINE RD @ SPRINGHILL RD  386913.98058
# 20      21      8TH LINE RD btwn ANDREW SIMPSON DR & BRUCE ST  385271.41528
# 21      22  8TH LINE RD btwn COOPER HILL RD & FOREST GREEN...  384041.04310
# 22      23      8TH LINE RD btwn MARVELVILLE RD & LAWRENCE ST  387737.81575
# 23      24   8TH LINE RD btwn MITCH OWENS RD & RODNEY FARM DR  382555.31466
# 24      25       8TH LINE RD btwn PANA RD & ANDREW SIMPSON DR  384774.52770
# 25      26       8TH LINE RD btwn PANA RD & ANDREW SIMPSON DR  384864.51831
# 26      27    8TH LINE RD btwn SPRINGHILL RD & MARVELVILLE RD  387003.33245
# 27      28                          9TH LINE RD @ VICTORIA ST  387131.38688
# 28      29          AARON AVE btwn CARLING AVE & LENESTER AVE  362166.07500
# 29      30                      ABBEYHILL DR @ CASTLEFRANK RD  353223.51580
# 30      31                         ABBEYHILL DR @ EAGLESON RD  353827.56558
# 31      32                         ABBEYHILL DR @ SURREY LANE  353673.10680
# 32      33       ABBEYHILL DR btwn OLD COLONY RD & BALBAIR RD  353492.38954
# 33      34        ABBEYHILL DR btwn SURREY LANE & EAGLESON RD  353730.31950
# 34      35                       ABBOTT ST @ GRANITE RIDGE DR  351484.20222
# 7    03 - Snow          06 - Ice      03 - Yield sign
# 8   01 - Clear          01 - Dry      10 - No control
# 9   01 - Clear          01 - Dry      10 - No control
# 10   02 - Rain          02 - Wet      10 - No control
# 11  01 - Clear          01 - Dry      10 - No control
# 12  01 - Clear          01 - Dry      10 - No control
# 13  01 - Clear          01 - Dry       02 - Stop sign
# 14  01 - Clear          01 - Dry       02 - Stop sign
# 15  01 - Clear          02 - Wet       02 - Stop sign
# 16   03 - Snow   03 - Loose snow       02 - Stop sign
# 17  01 - Clear          02 - Wet       02 - Stop sign
# 18  01 - Clear          01 - Dry       02 - Stop sign
# 19  01 - Clear          01 - Dry       02 - Stop sign
# 20  01 - Clear          01 - Dry      10 - No control
# 21  01 - Clear          02 - Wet      10 - No control
# 22  01 - Clear          01 - Dry      10 - No control
# 23  01 - Clear          01 - Dry      10 - No control
# 24  01 - Clear          01 - Dry      10 - No control
# 25  01 - Clear          01 - Dry      10 - No control
# 26  01 - Clear          01 - Dry      10 - No control
# 27  01 - Clear          01 - Dry       02 - Stop sign
# 28   02 - Rain          02 - Wet      10 - No control
# 29  01 - Clear          01 - Dry       02 - Stop sign
# 30  01 - Clear          01 - Dry  01 - Traffic signal
# 31   03 - Snow  05 - Packed snow       02 - Stop sign
# 32  01 - Clear          01 - Dry      10 - No control
# 33   02 - Rain          02 - Wet      10 - No control
# 34   02 - Rain          02 - Wet       02 - Stop sign
# 35  01 - Clear          02 - Wet       02 - Stop sign
# 36  01 - Clear          01 - Dry      10 - No control
# 37   02 - Rain          02 - Wet      10 - No control
# 38  01 - Clear          01 - Dry       02 - Stop sign
# 39  01 - Clear          01 - Dry  01 - Traffic signal
# 40   02 - Rain          02 - Wet  01 - Traffic signal
# 41  01 - Clear          01 - Dry  01 - Traffic signal
# 42   02 - Rain          02 - Wet       02 - Stop sign
# 43  01 - Clear          01 - Dry       02 - Stop sign
# 44   03 - Snow   03 - Loose snow       02 - Stop sign
# 45  01 - Clear          01 - Dry      10 - No control
# 46  01 - Clear          01 - Dry      10 - No control
# 47  01 - Clear          06 - Ice      10 - No control
# 48  01 - Clear          01 - Dry       02 - Stop sign
# 49  01 - Clear  05 - Packed snow       02 - Stop sign
# 50   02 - Rain          02 - Wet       02 - Stop sign
#
#             Collision_Location          Light Collision_Classification  \
# 0    02 - Intersection related  01 - Daylight    02 - Non-fatal injury
# 1         03 - At intersection  01 - Daylight           03 - P.D. only
# 2    02 - Intersection related  01 - Daylight    02 - Non-fatal injury
# 3    02 - Intersection related  01 - Daylight           03 - P.D. only
# 4    02 - Intersection related  01 - Daylight           03 - P.D. only
# 5         03 - At intersection      05 - Dusk    02 - Non-fatal injury
# 6    02 - Intersection related      07 - Dark           03 - P.D. only
# 7         03 - At intersection  01 - Daylight           03 - P.D. only
# 8        01 - Non intersection      07 - Dark           03 - P.D. only
# 9        01 - Non intersection  01 - Daylight           03 - P.D. only
# 10       01 - Non intersection  01 - Daylight           03 - P.D. only
# 11       01 - Non intersection  01 - Daylight           03 - P.D. only
# 12   02 - Intersection related      07 - Dark    02 - Non-fatal injury
# 13   02 - Intersection related  01 - Daylight           03 - P.D. only
# 14   02 - Intersection related  01 - Daylight    02 - Non-fatal injury
# 15        03 - At intersection      05 - Dusk           03 - P.D. only
# 16        03 - At intersection      07 - Dark           03 - P.D. only
# 17        03 - At intersection  01 - Daylight    02 - Non-fatal injury
# 18        03 - At intersection  01 - Daylight        01 - Fatal injury
# 19        03 - At intersection  01 - Daylight           03 - P.D. only
# 20       01 - Non intersection  01 - Daylight    02 - Non-fatal injury
# 21       01 - Non intersection      07 - Dark           03 - P.D. only
# 22       01 - Non intersection  01 - Daylight           03 - P.D. only
# 23       01 - Non intersection      07 - Dark    02 - Non-fatal injury
# 24       01 - Non intersection  01 - Daylight           03 - P.D. only
# 25       01 - Non intersection  01 - Daylight           03 - P.D. only
# 26       01 - Non intersection  01 - Daylight    02 - Non-fatal injury
# 27        03 - At intersection  01 - Daylight           03 - P.D. only
# 28       01 - Non intersection      05 - Dusk           03 - P.D. only
# 29        03 - At intersection  01 - Daylight    02 - Non-fatal injury
# 30   02 - Intersection related  01 - Daylight           03 - P.D. only
# 31   02 - Intersection related  01 - Daylight           03 - P.D. only
# 32  04 - At/near private drive  01 - Daylight           03 - P.D. only
# 33  04 - At/near private drive      03 - Dawn           03 - P.D. only
# 34        03 - At intersection  01 - Daylight           03 - P.D. only
# 35        03 - At intersection  01 - Daylight    02 - Non-fatal injury
# 36   02 - Intersection related  01 - Daylight           03 - P.D. only
# 37   02 - Intersection related  01 - Daylight           03 - P.D. only
# 38   02 - Intersection related      07 - Dark           03 - P.D. only
# 39        03 - At intersection  01 - Daylight           03 - P.D. only
# 40   02 - Intersection related  01 - Daylight    02 - Non-fatal injury
# 41   02 - Intersection related  01 - Daylight           03 - P.D. only
# 42   02 - Intersection related  01 - Daylight    02 - Non-fatal injury
# 43        03 - At intersection  01 - Daylight           03 - P.D. only
# 44   02 - Intersection related   00 - Unknown           03 - P.D. only
# 45       01 - Non intersection   00 - Unknown           03 - P.D. only
# 46  04 - At/near private drive   00 - Unknown           03 - P.D. only
# 47       01 - Non intersection      07 - Dark           03 - P.D. only
# 48        03 - At intersection  01 - Daylight    02 - Non-fatal injury
# 49        03 - At intersection  01 - Daylight           03 - P.D. only
# 50   02 - Intersection related      07 - Dark           03 - P.D. only
#
#                     Impact_type
# 0                 03 - Rear end
# 1         05 - Turning movement
# 2                 03 - Rear end
# 3                 03 - Rear end
# 4                 03 - Rear end
# 5         05 - Turning movement
# 6                 03 - Rear end
# 7                07 - SMV other
# 8                07 - SMV other
# 9                07 - SMV other
# 10               07 - SMV other
# 11               07 - SMV other
# 12               07 - SMV other
# 13               07 - SMV other
# 14                03 - Rear end
# 15        05 - Turning movement
# 16               07 - SMV other
# 17                   02 - Angle
# 18                   02 - Angle
# 19                   02 - Angle
# 20                03 - Rear end
# 21               07 - SMV other
# 22                   99 - Other
# 23                03 - Rear end
# 24               07 - SMV other
# 25               07 - SMV other
# 26               07 - SMV other
# 27                   02 - Angle
# 28  06 - SMV unattended vehicle
# 29                   02 - Angle
# 30                03 - Rear end
# 31                03 - Rear end
# 32                   99 - Other
# 33                   02 - Angle
# 34                   02 - Angle
# 35                   02 - Angle
# 36                03 - Rear end
# 37                03 - Rear end
# 38               07 - SMV other
# 39               07 - SMV other
# 40                03 - Rear end
# 41                   99 - Other
# 42                03 - Rear end
# 43                   02 - Angle
# 44  06 - SMV unattended vehicle
# 45  06 - SMV unattended vehicle
# 46  06 - SMV unattended vehicle
# 47  06 - SMV unattended vehicle
# 48        05 - Turning movement
# 49                   02 - Angle
# 50               07 - SMV other

# %% [markdown]
# Create the dimensions for location, accident and weather

# %%
Accident_dimension = pd.DataFrame(columns=['Accident_surogate_key','Accident_ID', 'Environment', 'Road_Surface', 'Traffic_Control',
                                     'Visibility', 'Impact_Type'])

Location_dimension = pd.DataFrame(columns=['Location_ID','Street_Name', 'Intersection_1', 'Intersection_2', 'Longitude', 'Latitude'])

# %%
for idx, row in collisions.iterrows():
    
    #Accident
    accident_row = [idx + 100]
    accident_row.append(row["Record"])
    accident_row.append(row['Environment'][4:].strip()) 
    accident_row.append(row['Road_Surface'][4:].strip()) 
    accident_row.append(row['Traffic_Control'][4:].strip()) 
    accident_row.append(row['Light'][4:].strip())  
    accident_row.append(row['Impact_type'][4:].strip())
    Accident_dimension.loc[len(Accident_dimension)] = accident_row
    
    
    #Location
    location_row = [idx]
    if '@' in row['Location']: 
        roads = row['Location'].split("@")
        location_row += [roads[0].strip(), roads[1].strip(), "NA"] #Street, Intersection 1, Intersection 2
        
    else: #when there is a btwn in the location
        roads = row['Location'].split("btwn")
        
        if "&" in roads[1]:
            intersections = roads[1].split("&")
            location_row += [roads[0].strip(), intersections[0].strip(), 
                             intersections[1].strip()] #Street, Intersection 1, Intersection 2
        else:
            location_row += [roads[0].strip(), roads[1].strip(), "NA"] #Street, Intersection 1, Intersection 2
        
    location_row += [row['Longitude'], row['Latitude']]
    
    Location_dimension.loc[len(Location_dimension)] = location_row

# %%
Accident_dimension.to_csv("accident_dimension.csv",index=False)

# %%
Accident_dimension.head()
# Out:
#   Accident_surogate_key Accident_ID Environment Road_Surface Traffic_Control  \
# 0                   100           1       Clear          Wet  Traffic signal
# 1                   101           2       Clear          Dry  Traffic signal
# 2                   102           3       Clear          Dry  Traffic signal
# 3                   103           4        Snow   Loose snow  Traffic signal
# 4                   104           5        Rain          Wet  Traffic signal
#
#   Visibility       Impact_Type
# 0   Daylight          Rear end
# 1   Daylight  Turning movement
# 2   Daylight          Rear end
# 3   Daylight          Rear end
# 4   Daylight          Rear end

# %%
Location_dimension = Location_dimension.drop_duplicates(subset=['Longitude','Latitude'])
Location_dimension.insert(0, "surrogate_key",  np.arange(len(Location_dimension)))

# %%
Location_dimension.head()
# Out:
#    surrogate_key Location_ID                       Street_Name  \
# 0              0           0              210 W OF MERIVALE RD
# 1              1           1              210 W OF MERIVALE RD
# 4              2           4              210 W OF MERIVALE RD
# 6              3           6  225 E OF RIVERSIDE DR / T & T SC
# 7              4           7                       2ND LINE RD
#
#       Intersection_1 Intersection_2  Longitude  Latitude
# 0  WEST HUNT CLUB RD             NA  -75.72644  45.33379
# 1  WEST HUNT CLUB RD             NA  -75.72645  45.33380
# 4  WEST HUNT CLUB RD             NA  -75.72643  45.33379
# 6       HUNT CLUB RD             NA  -75.69064  45.33558
# 7           CABIN RD             NA  -75.59877  45.16056

# %%
Location_dimension.to_csv("location_dimension.csv",index=False)

# %% [markdown]
# Pre-process weather

# %%
climate = pd.read_csv("climate-daily.csv")
# Out:
# /Users/parlos/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (33,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
climate[climate["STATION_NAME"].str.match("OTTAWA")].head()
# Out:
#                x          y STATION_NAME CLIMATE_IDENTIFIER                ID  \
# 28483 -75.716667  45.383333   OTTAWA CDA            6105976  6105976.2016.8.1
# 28484 -75.716667  45.383333   OTTAWA CDA            6105976  6105976.2016.8.2
# 28485 -75.716667  45.383333   OTTAWA CDA            6105976  6105976.2016.8.3
# 28486 -75.716667  45.383333   OTTAWA CDA            6105976  6105976.2016.8.4
# 28487 -75.716667  45.383333   OTTAWA CDA            6105976  6105976.2016.8.5
#
#                 LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY  \
# 28483  2016-08-01 00:00:00            ON        2016            8          1
# 28484  2016-08-02 00:00:00            ON        2016            8          2
# 28485  2016-08-03 00:00:00            ON        2016            8          3
# 28486  2016-08-04 00:00:00            ON        2016            8          4
# 28487  2016-08-05 00:00:00            ON        2016            8          5
#
#        ...  SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  COOLING_DEGREE_DAYS  \
# 28483  ...             NaN                 NaN                  5.8
# 28484  ...             NaN                 NaN                  4.3
# 28485  ...             NaN                 NaN                  4.5
# 28486  ...             NaN                 NaN                  7.8
# 28487  ...             NaN                 NaN                  8.0
#
#       COOLING_DEGREE_DAYS_FLAG  HEATING_DEGREE_DAYS HEATING_DEGREE_DAYS_FLAG  \
# 28483                      NaN                  0.0                      NaN
# 28484                      NaN                  0.0                      NaN
# 28485                      NaN                  0.0                      NaN
# 28486                      NaN                  0.0                      NaN
# 28487                      NaN                  0.0                      NaN
#
#        MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  MAX_REL_HUMIDITY  \
# 28483               NaN                   NaN               NaN
# 28484               NaN                   NaN               NaN
# 28485               NaN                   NaN               NaN
# 28486               NaN                   NaN               NaN
# 28487               NaN                   NaN               NaN
#
#       MAX_REL_HUMIDITY_FLAG
# 28483                   NaN
# 28484                   NaN
# 28485                   NaN
# 28486                   NaN
# 28487                   NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# Easy solution - Choosing one station (OTTAWA INTL A)

# %%
ottawa_climate = climate[climate["STATION_NAME"] == ("OTTAWA INTL A")]

# %% [markdown]
# Deleting the columns with most missing values

# %%
ottawa_climate = ottawa_climate[['x', 'y', 'STATION_NAME', 'CLIMATE_IDENTIFIER', 'ID', 'LOCAL_DATE',
       'PROVINCE_CODE', 'LOCAL_YEAR', 'LOCAL_MONTH', 'LOCAL_DAY','MEAN_TEMPERATURE',  'MIN_TEMPERATURE',
       'MAX_TEMPERATURE', 
       'TOTAL_PRECIPITATION',  'TOTAL_RAIN',
        'TOTAL_SNOW', 'DIRECTION_MAX_GUST', 
       'SPEED_MAX_GUST', 'COOLING_DEGREE_DAYS',
      'HEATING_DEGREE_DAYS']]

# %% [markdown]
# Adding the sorrogate key to the weather dimension.

# %%
ottawa_climate.insert(0, "surrogate_key",  np.arange(len(ottawa_climate)))

# %%
ottawa_climate["LOCAL_DATE"] = pd.to_datetime(ottawa_climate["LOCAL_DATE"] ).dt.strftime('%Y-%m-%d')

# %%
ottawa_climate['ID'] = ottawa_climate['ID'].str.replace('.','')

# %%
ottawa_climate = ottawa_climate.dropna()

# %%
weather_dimension = ottawa_climate

# %%
weather_dimension.to_csv("weather_dimension.csv",index=False)

# %%
weather_dimension.head()
# Out:
#        surrogate_key          x          y   STATION_NAME CLIMATE_IDENTIFIER  \
# 29512              0 -75.666667  45.316667  OTTAWA INTL A            6106001
# 29513              1 -75.666667  45.316667  OTTAWA INTL A            6106001
# 29514              2 -75.666667  45.316667  OTTAWA INTL A            6106001
# 29515              3 -75.666667  45.316667  OTTAWA INTL A            6106001
# 29516              4 -75.666667  45.316667  OTTAWA INTL A            6106001
#
#                   ID  LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  LOCAL_MONTH  ...  \
# 29512  6106001201681  2016-08-01            ON        2016            8  ...
# 29513  6106001201682  2016-08-02            ON        2016            8  ...
# 29514  6106001201683  2016-08-03            ON        2016            8  ...
# 29515  6106001201684  2016-08-04            ON        2016            8  ...
# 29516  6106001201685  2016-08-05            ON        2016            8  ...
#
#        MEAN_TEMPERATURE  MIN_TEMPERATURE  MAX_TEMPERATURE  \
# 29512              23.6             16.8             30.3
# 29513              22.6             14.9             30.3
# 29514              22.8             14.0             31.6
# 29515              26.2             18.2             34.2
# 29516              25.8             18.5             33.1
#
#        TOTAL_PRECIPITATION  TOTAL_RAIN  TOTAL_SNOW  DIRECTION_MAX_GUST  \
# 29512                  0.0         0.0         0.0                 8.0
# 29513                  0.0         0.0         0.0                 7.0
# 29514                  0.0         0.0         0.0                20.0
# 29515                  0.0         0.0         0.0                24.0
# 29516                  0.0         0.0         0.0                18.0
#
#        SPEED_MAX_GUST  COOLING_DEGREE_DAYS  HEATING_DEGREE_DAYS
# 29512            41.0                  5.6                  0.0
# 29513            35.0                  4.6                  0.0
# 29514            33.0                  4.8                  0.0
# 29515            33.0                  8.2                  0.0
# 29516            50.0                  7.8                  0.0
#
# [5 rows x 21 columns]
